# %%
import requests, openpyxl
from bs4 import BeautifulSoup
from openpyxl import Workbook

# %%
query = {'year' : '2023', 'level':'Elementary', 'appID': 'WgDidVYQKbiWz0LufFHc6KGHF2MwrDlC', 'appKey': ''}
#url = 'https://api.nytimes.com/svc/books/v3/lists/names.json'
url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'

# %%
try:
  response=requests.get("https://api.schooldigger.com/v1/rankings/schools/TX")
  soup=BeautifulSoup(response.text,'html.parser')
  print(soup)
except Exception as e:
  print(e)
# Out:
# {
#   "code": 401,
#   "message": "Unauthorized",
#   "description": "Must supply appID in query string",
#   "help": "For documentation, please see https://developer.schooldigger.com/docs/ or Email us at api@schooldigger.com"
# }
# <ipython-input-20-da194e6f9d09>:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup=BeautifulSoup(response.text,'html.parser')

# %%
response.status_code
# Out:
# 403

# %%
query = {'section_name' : 'Movies', 'type_of_material':'Review', 'api-key': 'WgDidVYQKbiWz0LufFHc6KGHF2MwrDlC'}
#url = 'https://api.nytimes.com/svc/books/v3/lists/names.json'
url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'

# %%
response = requests.get(url, params=query)

# %%
response.status_code
# Out:
# 200

# %%
response.ok
# Out:
# True

# %%
data = response.json()
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'President Biden met with the top four lawmakers in the Oval Office to discuss the war in Ukraine, the U.S.-Mexico border and ways to avoid the looming government shutdown.',
#     'web_url': 'https://www.nytimes.com/video/us/politics/100000009332851/biden-congress-shutdown.html',
#     'snippet': 'President Biden met with the top four lawmakers in the Oval Office to discuss the war in Ukraine, the U.S.-Mexico border and ways to avoid the looming government shutdown.',
#     'lead_paragraph': 'President Biden met with the top four lawmakers in the Oval Office to discuss the war in Ukraine, the U.S.-Mexico border and ways to avoid the looming government shutdown.',
#     'source': 'Reuters',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
# ...

# %%
  # Get just the results
  raw_incidents = data['results']

# %%
  # Iterate the results and only grab the properties that you are interested in
  books = [{
      'list_name':book['list_name'],
      'display_name': book['display_name'],
      'list_name_encoded': book['list_name_encoded'],
      'oldest_published_date': book['oldest_published_date'],
      'newest_published_date': book['newest_published_date'],
      'updated': book['updated']
  } for book in raw_incidents]
  # Print five items to see if this worked
  print(books[:5])
# Out:
# [{'list_name': 'Combined Print and E-Book Fiction', 'display_name': 'Combined Print & E-Book Fiction', 'list_name_encoded': 'combined-print-and-e-book-fiction', 'oldest_published_date': '2011-02-13', 'newest_published_date': '2024-03-03', 'updated': 'WEEKLY'}, {'list_name': 'Combined Print and E-Book Nonfiction', 'display_name': 'Combined Print & E-Book Nonfiction', 'list_name_encoded': 'combined-print-and-e-book-nonfiction', 'oldest_published_date': '2011-02-13', 'newest_published_date': '2024-03-03', 'updated': 'WEEKLY'}, {'list_name': 'Hardcover Fiction', 'display_name': 'Hardcover Fiction', 'list_name_encoded': 'hardcover-fiction', 'oldest_published_date': '2008-06-08', 'newest_published_date': '2024-03-03', 'updated': 'WEEKLY'}, {'list_name': 'Hardcover Nonfiction', 'display_name': 'Hardcover Nonfiction', 'list_name_encoded': 'hardcover-nonfiction', 'oldest_published_date': '2008-06-08', 'newest_published_date': '2024-03-03', 'updated': 'WEEKLY'}, {'list_name': 'Trade Fiction Pa
# ...
